# %% [markdown]
# # Import FAOSTAT Data
# ---

# %%
# Load dependencies
import pandas as pd
import faostat

# %% [markdown]
# ## Inspect Datasets
# ---

# %%
# List available datasets
faostat.list_datasets_df()[['code','label']].to_dict('split')['data']
# Out:
# [['QCL', 'Crops and livestock products'],
#  ['QI', 'Production Indices'],
#  ['QV', 'Value of Agricultural Production'],
#  ['FS', 'Suite of Food Security Indicators'],
#  ['FBS', 'Food Balances (2010-)'],
#  ['SCL', 'Supply Utilization Accounts (2010-)'],
#  ['CB', 'Commodity Balances (non-food) (2010-)'],
#  ['FBSH', 'Food Balances (-2013, old methodology and population)'],
#  ['CBH', 'Commodity Balances (non-food) (-2013, old methodology)'],
#  ['TCL', 'Crops and livestock products'],
#  ['TM', 'Detailed trade matrix'],
#  ['TI', 'Trade Indices'],
#  ['PP', 'Producer Prices'],
#  ['CP', 'Consumer Price Indices'],
#  ['PD', 'Deflators'],
#  ['PE', 'Exchange rates'],
#  ['CAHD', 'Cost and Affordability of a Healthy Diet (CoAHD)'],
#  ['SUA', 'Availability (based on supply utilization accounts)'],
#  ['HCES',
#   'Apparent intake (based on household consumption and expenditure surveys)'],
#  ['FDIQ', 'Intake (based on individual quantitative dietary surveys)'],
#  ['MDDW',
#   'Diversity (MDD-W, based on individual qualitative dietary surveys)'],
#  ['RL', 'Land Use'],
#  ['LC', 'Land Cover'],
#  ['RFN', 'Fertilizers by Nutrient'],
#  ['RFB', 'Fertilizers by Product'],
#  ['RFM', 'Detailed trade matrix (fertilizers)'],
#  ['EMN', 'Livestock Manure'],
#  ['RP', 'Pesticides Use'],
#  ['RT', 'Pesticides Trade'],
#  ['ESB', 'Cropland Nutrient Balance'],
#  ['EK', 'Livestock Patterns'],
#  ['BE', 'Bioenergy'],
#  ['ET', 'Temperature change on land'],
#  ['OA', 'Annual population'],
#  ['OEA', 'Employment Indicators: Agriculture'],
#  ['OER', 'Employment Indicators: Rural'],
#  ['IG', 'Government Expenditure'],
#  ['IC', 'Credit to Agriculture'],
#  ['EA', 'Development Flows to Agriculture'],
#  ['FDI', 'Foreign Direct Investment (FDI)'],
#  ['CISP', 'Country Investment Statistics Profile'],
#  ['MK', 'Macro Indicators'],
#  ['CS', 'Capital Stock'],
#  ['GFDI', 'Value shares by industry and primary factors'],
#  ['GT', 'Emissions totals'],
#  ['EM', 'Emissions indicators'],
#  ['EI', 'Emissions intensities'],
#  ['GCE', 'Emissions from Crops'],
#  ['GLE', 'Emissions from Livestock'],
#  ['GN', 'Emissions from Energy use in agriculture'],
#  ['GF', 'Emissions from Forests'],
#  ['GI', 'Emissions from Fires'],
#  ['GV', 'Emissions from Drained organic soils'],
#  ['GPP', 'Emissions from pre and post agricultural production'],
#  ['FO', 'Forestry Production and Trade'],
#  ['SDGB', 'SDG Indicators'],
#  ['WCAD', 'Structural data from agricultural censuses'],
#  ['FT', 'Forestry Trade Flows'],
#  ['HS', 'Indicators from Household Surveys (gender, area, socioeconomics)'],
#  ['AF', 'ASTI-Researchers'],
#  ['AE', 'ASTI-Expenditures'],
#  ['FA', 'Food Aid Shipments (WFP)'],
#  ['RM', 'Machinery'],
#  ['RY', 'Machinery Archive'],
#  ['RA', 'Fertilizers archive'],
#  ['PA', 'Producer Prices (old series)']]

# %% [markdown]
# ## Inspect QCL Data
# ---

# %%
# List parameters for 'Crops and livestock products'
faostat.list_pars('QCL')
# Out:
# [('parameter code', 'coding_systems', 'subdimensions {code: meaning}'),
#  ('area',
#   ['M49', 'FAO', 'ISO2', 'ISO3'],
#   {'countries': 'Countries',
#    'regions': 'Regions',
#    'specialgroups': 'Special Groups'}),
#  ('element', [], {'elements': 'Elements'}),
#  ('item', ['CPC', 'FAO'], {'items': 'Items', 'itemsagg': 'Items Aggregated'}),
#  ('year', [], {'years': 'Years'})]

# %%
# List products and their codes
faostat.get_par('QCL', 'item')
# Out:
# {'Abaca, manila hemp, raw': '809',
#  'Agave fibres, raw, n.e.c.': '800',
#  'Almonds, in shell': '221',
#  'Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw': '711',
#  'Apples': '515',
#  'Apricots': '526',
#  'Areca nuts': '226',
#  'Artichokes': '366',
#  'Asparagus': '367',
#  'Asses': '1107',
#  'Avocados': '572',
#  'Balata, gutta-percha, guayule, chicle and similar natural gums in primary forms or in plates, sheets or strip': '839',
#  'Bambara beans, dry': '203',
#  'Bananas': '486',
#  'Barley': '44',
#  'Beans, dry': '176',
#  'Beer of barley, malted': '51',
#  'Bees': '1181',
#  'Beeswax': '1183',
#  'Blueberries': '552',
#  'Brazil nuts, in shell': '216',
#  'Broad beans and horse beans, dry': '181',
#  'Broad beans and horse beans, green': '420',
#  'Buckwheat': '89',
#  'Buffalo': '946',
#  'Buffalo fat, unrendered': '949',
#  'Butter and ghee of sheep milk': '983',
#  'Butter of buffalo milk': '952',
#  'Butter of cow milk': '886',
#  'Butter of goat milk': '1022',
#  'Buttermilk, dry': '899',
#  'Cabbages': '358',
#  'Camels': '1126',
#  'Canary seed': '101',
#  'Cantaloupes and other melons': '568',
#  'Carrots and turnips': '426',
#  'Cashew nuts, in shell': '217',
#  'Cashewapple': '591',
#  'Cassava leaves': '378',
#  'Cassava, fresh': '125',
#  'Castor oil seeds': '265',
#  'Cattle': '866',
#  'Cattle fat, unrendered': '869',
#  'Cauliflowers and broccoli': '393',
#  'Cereals n.e.c.': '108',
#  'Cheese from milk of buffalo, fresh or processed': '955',
#  'Cheese from milk of goats, fresh or processed': '1021',
#  'Cheese from milk of sheep, fresh or processed': '984',
#  'Cheese from skimmed cow milk': '904',
#  'Cheese from whole cow milk': '901',
#  'Cherries': '531',
#  'Chestnuts, in shell': '220',
#  'Chick peas, dry': '191',
#  'Chickens': '1057',
#  'Chicory roots': '459',
#  'Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw': '689',
#  'Chillies and peppers, green (Capsicum spp. and Pimenta spp.)': '401',
#  'Cinnamon and cinnamon-tree flowers, raw': '693',
#  'Cloves (whole stems), raw': '698',
#  'Cocoa beans': '661',
#  'Coconut oil': '252',
#  'Coconuts, in shell': '249',
#  'Coffee, green': '656',
#  'Coir, raw': '813',
#  'Cotton lint, ginned': '767',
#  'Cotton seed': '329',
#  'Cottonseed oil': '331',
#  'Cow peas, dry': '195',
#  'Cranberries': '554',
#  'Cream, fresh': '885',
#  'Cucumbers and gherkins': '397',
#  'Currants': '550',
#  'Dates': '577',
#  'Ducks': '1068',
#  'Edible offal of buffalo, fresh, chilled or frozen': '948',
#  'Edible offal of cattle, fresh, chilled or frozen': '868',
#  'Edible offal of goat, fresh, chilled or frozen': '1018',
#  'Edible offal of pigs, fresh, chilled or frozen': '1036',
#  'Edible offal of sheep, fresh, chilled or frozen': '978',
#  'Edible offals of camels and other camelids, fresh, chilled or frozen': '1128',
#  'Edible offals of horses and other equines,  fresh, chilled or frozen': '1098',
#  'Edible roots and tubers with high starch or inulin content, n.e.c., fresh': '149',
#  'Eggplants (aubergines)': '399',
#  'Eggs from other birds in shell, fresh, n.e.c.': '1091',
#  'Fat of camels': '1129',
#  'Fat of pigs': '1037',
#  'Figs': '569',
#  'Flax, raw or retted': '771',
#  'Fonio': '94',
#  'Game meat, fresh, chilled or frozen': '1163',
#  'Geese': '1072',
#  'Ghee from buffalo milk': '953',
#  'Ghee from cow milk': '887',
#  'Ginger, raw': '720',
#  'Goat fat, unrendered': '1019',
#  'Goats': '1016',
#  'Gooseberries': '549',
#  'Grapes': '560',
#  'Green corn (maize)': '446',
#  'Green garlic': '406',
#  'Green tea (not fermented), black tea (fermented) and partly fermented tea, in immediate packings of a content not exceeding 3 kg': '675',
#  'Groundnut oil': '244',
#  'Groundnuts, excluding shelled': '242',
#  'Hazelnuts, in shell': '225',
#  'Hempseed': '336',
#  'Hen eggs in shell, fresh': '1062',
#  'Hop cones': '677',
#  'Horse meat, fresh or chilled': '1097',
#  'Horses': '1096',
#  'Jojoba seeds': '277',
#  'Jute, raw or retted': '780',
#  'Kapok fibre, raw': '778',
#  'Kapok fruit': '310',
#  'Kapokseed in shell': '311',
#  'Karite nuts (sheanuts)': '263',
#  'Kenaf, and other textile bast fibres, raw or retted': '782',
#  'Kiwi fruit': '592',
#  'Kola nuts': '224',
#  'Leeks and other alliaceous vegetables': '407',
#  'Lemons and limes': '497',
#  'Lentils, dry': '201',
#  'Lettuce and chicory': '372',
#  'Linseed': '333',
#  'Locust beans (carobs)': '461',
#  'Lupins': '210',
#  'Maize (corn)': '56',
#  'Mangoes, guavas and mangosteens': '571',
#  'Margarine and shortening': '1242',
#  'Maté leaves': '671',
#  'Meat of asses, fresh or chilled': '1108',
#  'Meat of buffalo, fresh or chilled': '947',
#  'Meat of camels, fresh or chilled': '1127',
#  'Meat of cattle with the bone, fresh or chilled': '867',
#  'Meat of chickens, fresh or chilled': '1058',
#  'Meat of ducks, fresh or chilled': '1069',
#  'Meat of geese, fresh or chilled': '1073',
#  'Meat of goat, fresh or chilled': '1017',
#  'Meat of mules, fresh or chilled': '1111',
#  'Meat of other domestic camelids, fresh or chilled': '1158',
#  'Meat of other domestic rodents, fresh or chilled': '1151',
#  'Meat of pig with the bone, fresh or chilled': '1035',
#  'Meat of pigeons and other birds n.e.c., fresh, chilled or frozen': '1089',
#  'Meat of rabbits and hares, fresh or chilled': '1141',
#  'Meat of sheep, fresh or chilled': '977',
#  'Meat of turkeys, fresh or chilled': '1080',
#  'Melonseed': '299',
#  'Millet': '79',
#  'Mixed grain': '103',
#  'Molasses': '165',
#  'Mules and hinnies': '1110',
#  'Mushrooms and truffles': '449',
#  'Mustard seed': '292',
#  'Natural honey': '1182',
#  'Natural rubber in primary forms': '836',
#  'Nutmeg, mace, cardamoms, raw': '702',
#  'Oats': '75',
#  'Oil of linseed': '334',
#  'Oil of maize': '60',
#  'Oil of palm kernel': '258',
#  'Oil of sesame seed': '290',
#  'Oil palm fruit': '254',
#  'Okra': '430',
#  'Olive oil': '261',
#  'Olives': '260',
#  'Onions and shallots, dry (excluding dehydrated)': '403',
#  'Onions and shallots, green': '402',
#  'Oranges': '490',
#  'Other beans, green': '414',
#  'Other berries and fruits of the genus vaccinium n.e.c.': '558',
#  'Other birds': '1083',
#  'Other camelids': '1157',
#  'Other citrus fruit, n.e.c.': '512',
#  'Other fibre crops, raw, n.e.c.': '821',
#  'Other fruits, n.e.c.': '619',
#  'Other meat n.e.c. (excluding mammals), fresh, chilled or frozen': '1166',
#  'Other nuts (excluding wild edible nuts and groundnuts), in shell, n.e.c.': '234',
#  'Other oil seeds, n.e.c.': '339',
#  'Other pome fruits': '542',
#  'Other pulses n.e.c.': '211',
#  'Other rodents': '1150',
#  'Other stimulant, spice and aromatic crops, n.e.c.': '723',
#  'Other stone fruits': '541',
#  'Other sugar crops n.e.c.': '161',
#  'Other tropical fruits, n.e.c.': '603',
#  'Other vegetables, fresh n.e.c.': '463',
#  'Palm kernels': '256',
#  'Palm oil': '257',
#  'Papayas': '600',
#  'Peaches and nectarines': '534',
#  'Pears': '521',
#  'Peas, dry': '187',
#  'Peas, green': '417',
#  'Pepper (Piper spp.), raw': '687',
#  'Peppermint, spearmint': '748',
#  'Persimmons': '587',
#  'Pig fat, rendered': '1043',
#  'Pigeon peas, dry': '197',
#  'Pineapples': '574',
#  'Pistachios, in shell': '223',
#  'Plantains and cooking bananas': '489',
#  'Plums and sloes': '536',
#  'Pomelos and grapefruits': '507',
#  'Poppy seed': '296',
#  'Potatoes': '116',
#  'Pumpkins, squash and gourds': '394',
#  'Pyrethrum, dried flowers': '754',
#  'Quinces': '523',
#  'Quinoa': '92',
#  'Rabbits and hares': '1140',
#  'Ramie, raw or retted': '788',
#  'Rape or colza seed': '270',
#  'Rapeseed or canola oil, crude': '271',
#  'Raspberries': '547',
#  'Raw cane or beet sugar (centrifugal only)': '162',
#  'Raw hides and skins of buffaloes': '957',
#  'Raw hides and skins of cattle': '919',
#  'Raw hides and skins of goats or kids': '1025',
#  'Raw hides and skins of sheep or lambs': '995',
#  'Raw milk of buffalo': '951',
#  'Raw milk of camel': '1130',
#  'Raw milk of cattle': '882',
#  'Raw milk of goats': '1020',
#  'Raw milk of sheep': '982',
#  'Raw silk (not thrown)': '1186',
#  'Rice': '27',
#  'Rye': '71',
#  'Safflower seed': '280',
#  'Safflower-seed oil, crude': '281',
#  'Seed cotton, unginned': '328',
#  'Sesame seed': '289',
#  'Sheep': '976',
#  'Sheep fat, unrendered': '979',
#  'Shorn wool, greasy, including fleece-washed shorn wool': '987',
#  'Silk-worm cocoons suitable for reeling': '1185',
#  'Sisal, raw': '789',
#  'Skim milk and whey powder': '898',
#  'Skim milk of cows': '888',
#  'Skim milk, condensed': '896',
#  'Skim milk, evaporated': '895',
#  'Snails, fresh, chilled, frozen, dried, salted or in brine, except sea snails': '1176',
#  'Sorghum': '83',
#  'Sour cherries': '530',
#  'Soya bean oil': '237',
#  'Soya beans': '236',
#  'Spinach': '373',
#  'Strawberries': '544',
#  'String beans': '423',
#  'Sugar beet': '157',
#  'Sugar cane': '156',
#  'Sunflower seed': '267',
#  'Sunflower-seed oil, crude': '268',
#  'Sweet potatoes': '122',
#  'Swine / pigs': '1034',
#  'Tallow': '1225',
#  'Tallowtree seeds': '305',
#  'Tangerines, mandarins, clementines': '495',
#  'Taro': '136',
#  'Tea leaves': '667',
#  'Tomatoes': '388',
#  'Triticale': '97',
#  'True hemp, raw or retted': '777',
#  'Tung nuts': '275',
#  'Turkeys': '1079',
#  'Unmanufactured tobacco': '826',
#  'Vanilla, raw': '692',
#  'Vetches': '205',
#  'Walnuts, in shell': '222',
#  'Watermelons': '567',
#  'Wheat': '15',
#  'Whey, condensed': '890',
#  'Whey, dry': '900',
#  'Whole milk powder': '897',
#  'Whole milk, condensed': '889',
#  'Whole milk, evaporated': '894',
#  'Wine': '564',
#  'Yams': '137',
#  'Yautia': '135',
#  'Yoghurt': '891',
#  'Crops, primary > (List)': 'QC>',
#  'Crops Processed > (List)': 'QD>',
#  'Livestock primary > (List)': 'QL>',
#  'Livestock processed > (List)': 'QP>',
#  'Live Animals > (List)': 'QA>',
#  'Cereals, primary + (Total)': '1717',
#  'Cereals, primary > (List)': '1717>',
#  'Citrus Fruit, Total + (Total)': '1804',
#  'Citrus Fruit, Total > (List)': '1804>',
#  'Fibre Crops Primary > (List)': '1753>',
#  'Fibre Crops, Fibre Equivalent + (Total)': '17530',
#  'Fruit Primary + (Total)': '1738',
#  'Fruit Primary > (List)': '1738>',
#  'Oilcrops Primary > (List)': '1730>',
#  'Oilcrops, Cake Equivalent + (Total)': '1841',
#  'Oilcrops, Oil Equivalent + (Total)': '1732',
#  'Pulses, Total + (Total)': '1726',
#  'Pulses, Total > (List)': '1726>',
#  'Roots and Tubers, Total + (Total)': '1720',
#  'Roots and Tubers, Total > (List)': '1720>',
#  'Sugar Crops Primary + (Total)': '1723',
#  'Sugar Crops Primary > (List)': '1723>',
#  'Treenuts, Total + (Total)': '1729',
#  'Treenuts, Total > (List)': '1729>',
#  'Vegetables Primary + (Total)': '1735',
#  'Vegetables Primary > (List)': '1735>',
#  'Beef and Buffalo Meat, primary + (Total)': '1806',
#  'Beef and Buffalo Meat, primary > (List)': '1806>',
#  'Eggs Primary + (Total)': '1783',
#  'Eggs Primary > (List)': '1783>',
#  'Hides and skins, primary > (List)': '1777>',
#  'Meat, Poultry + (Total)': '1808',
#  'Meat, Poultry > (List)': '1808>',
#  'Meat, Total + (Total)': '1765',
#  'Meat, Total > (List)': '1765>',
#  'Milk, Total + (Total)': '1780',
#  'Milk, Total > (List)': '1780>',
#  'Sheep and Goat Meat + (Total)': '1807',
#  'Sheep and Goat Meat > (List)': '1807>',
#  'Butter and Ghee + (Total)': '1811',
#  'Butter and Ghee > (List)': '1811>',
#  'Cheese (All Kinds) + (Total)': '1745',
#  'Cheese (All Kinds) > (List)': '1745>',
#  'Evaporated & Condensed Milk + (Total)': '1816',
#  'Evaporated & Condensed Milk > (List)': '1816>',
#  'Skim Milk & Buttermilk, Dry + (Total)': '1809',
#  'Skim Milk & Buttermilk, Dry > (List)': '1809>',
#  'Cattle and Buffaloes + (Total)': '1746',
#  'Cattle and Buffaloes > (List)': '1746>',
#  'Poultry Birds + (Total)': '2029',
#  'Poultry Birds > (List)': '2029>',
#  'Sheep and Goats + (Total)': '1749',
#  'Sheep and Goats > (List)': '1749>'}

# %%
# List available data fields and their codes
faostat.get_par('QCL', 'element')
# Out:
# {'Area harvested': '2312',
#  'Yield': '2413',
#  'Production Quantity': '2510',
#  'Stocks': '2111',
#  'Producing Animals/Slaughtered': '2313'}

# %%
# List area names and their codes
faostat.get_par('QCL', 'area')
# Out:
# {'Afghanistan': '2',
#  'Albania': '3',
#  'Algeria': '4',
#  'Angola': '7',
#  'Antigua and Barbuda': '8',
#  'Argentina': '9',
#  'Armenia': '1',
#  'Australia': '10',
#  'Austria': '11',
#  'Azerbaijan': '52',
#  'Bahamas': '12',
#  'Bahrain': '13',
#  'Bangladesh': '16',
#  'Barbados': '14',
#  'Belarus': '57',
#  'Belgium': '255',
#  'Belgium-Luxembourg': '15',
#  'Belize': '23',
#  'Benin': '53',
#  'Bhutan': '18',
#  'Bolivia (Plurinational State of)': '19',
#  'Bosnia and Herzegovina': '80',
#  'Botswana': '20',
#  'Brazil': '21',
#  'Brunei Darussalam': '26',
#  'Bulgaria': '27',
#  'Burkina Faso': '233',
#  'Burundi': '29',
#  'Cabo Verde': '35',
#  'Cambodia': '115',
#  'Cameroon': '32',
#  'Canada': '33',
#  'Central African Republic': '37',
#  'Chad': '39',
#  'Chile': '40',
#  'China': '351',
#  'China, Hong Kong SAR': '96',
#  'China, Macao SAR': '128',
#  'China, mainland': '41',
#  'China, Taiwan Province of': '214',
#  'Colombia': '44',
#  'Comoros': '45',
#  'Congo': '46',
#  'Cook Islands': '47',
#  'Costa Rica': '48',
#  "Côte d'Ivoire": '107',
#  'Croatia': '98',
#  'Cuba': '49',
#  'Cyprus': '50',
#  'Czechia': '167',
#  'Czechoslovakia': '51',
#  "Democratic People's Republic of Korea": '116',
#  'Democratic Republic of the Congo': '250',
#  'Denmark': '54',
#  'Djibouti': '72',
#  'Dominica': '55',
#  'Dominican Republic': '56',
#  'Ecuador': '58',
#  'Egypt': '59',
#  'El Salvador': '60',
#  'Equatorial Guinea': '61',
#  'Eritrea': '178',
#  'Estonia': '63',
#  'Eswatini': '209',
#  'Ethiopia': '238',
#  'Ethiopia PDR': '62',
#  'Faroe Islands': '64',
#  'Fiji': '66',
#  'Finland': '67',
#  'France': '68',
#  'French Guiana': '69',
#  'French Polynesia': '70',
#  'Gabon': '74',
#  'Gambia': '75',
#  'Georgia': '73',
#  'Germany': '79',
#  'Ghana': '81',
#  'Greece': '84',
#  'Grenada': '86',
#  'Guadeloupe': '87',
#  'Guatemala': '89',
#  'Guinea': '90',
#  'Guinea-Bissau': '175',
#  'Guyana': '91',
#  'Haiti': '93',
#  'Honduras': '95',
#  'Hungary': '97',
#  'Iceland': '99',
#  'India': '100',
#  'Indonesia': '101',
#  'Iran (Islamic Republic of)': '102',
#  'Iraq': '103',
#  'Ireland': '104',
#  'Israel': '105',
#  'Italy': '106',
#  'Jamaica': '109',
#  'Japan': '110',
#  'Jordan': '112',
#  'Kazakhstan': '108',
#  'Kenya': '114',
#  'Kiribati': '83',
#  'Kuwait': '118',
#  'Kyrgyzstan': '113',
#  "Lao People's Democratic Republic": '120',
#  'Latvia': '119',
#  'Lebanon': '121',
#  'Lesotho': '122',
#  'Liberia': '123',
#  'Libya': '124',
#  'Lithuania': '126',
#  'Luxembourg': '256',
#  'Madagascar': '129',
#  'Malawi': '130',
#  'Malaysia': '131',
#  'Maldives': '132',
#  'Mali': '133',
#  'Malta': '134',
#  'Marshall Islands': '127',
#  'Martinique': '135',
#  'Mauritania': '136',
#  'Mauritius': '137',
#  'Mexico': '138',
#  'Micronesia (Federated States of)': '145',
#  'Mongolia': '141',
#  'Montenegro': '273',
#  'Morocco': '143',
#  'Mozambique': '144',
#  'Myanmar': '28',
#  'Namibia': '147',
#  'Nauru': '148',
#  'Nepal': '149',
#  'Netherlands (Kingdom of the)': '150',
#  'New Caledonia': '153',
#  'New Zealand': '156',
#  'Nicaragua': '157',
#  'Niger': '158',
#  'Nigeria': '159',
#  'Niue': '160',
#  'North Macedonia': '154',
#  'Norway': '162',
#  'Oman': '221',
#  'Pakistan': '165',
#  'Palestine': '299',
#  'Panama': '166',
#  'Papua New Guinea': '168',
#  'Paraguay': '169',
#  'Peru': '170',
#  'Philippines': '171',
#  'Poland': '173',
#  'Portugal': '174',
#  'Puerto Rico': '177',
#  'Qatar': '179',
#  'Republic of Korea': '117',
#  'Republic of Moldova': '146',
#  'Réunion': '182',
#  'Romania': '183',
#  'Russian Federation': '185',
#  'Rwanda': '184',
#  'Saint Kitts and Nevis': '188',
#  'Saint Lucia': '189',
#  'Saint Vincent and the Grenadines': '191',
#  'Samoa': '244',
#  'Sao Tome and Principe': '193',
#  'Saudi Arabia': '194',
#  'Senegal': '195',
#  'Serbia': '272',
#  'Serbia and Montenegro': '186',
#  'Seychelles': '196',
#  'Sierra Leone': '197',
#  'Singapore': '200',
#  'Slovakia': '199',
#  'Slovenia': '198',
#  'Solomon Islands': '25',
#  'Somalia': '201',
#  'South Africa': '202',
#  'South Sudan': '277',
#  'Spain': '203',
#  'Sri Lanka': '38',
#  'Sudan': '276',
#  'Sudan (former)': '206',
#  'Suriname': '207',
#  'Sweden': '210',
#  'Switzerland': '211',
#  'Syrian Arab Republic': '212',
#  'Tajikistan': '208',
#  'Thailand': '216',
#  'Timor-Leste': '176',
#  'Togo': '217',
#  'Tokelau': '218',
#  'Tonga': '219',
#  'Trinidad and Tobago': '220',
#  'Tunisia': '222',
#  'Türkiye': '223',
#  'Turkmenistan': '213',
#  'Tuvalu': '227',
#  'Uganda': '226',
#  'Ukraine': '230',
#  'United Arab Emirates': '225',
#  'United Kingdom of Great Britain and Northern Ireland': '229',
#  'United Republic of Tanzania': '215',
#  'United States of America': '231',
#  'Uruguay': '234',
#  'USSR': '228',
#  'Uzbekistan': '235',
#  'Vanuatu': '155',
#  'Venezuela (Bolivarian Republic of)': '236',
#  'Viet Nam': '237',
#  'Yemen': '249',
#  'Yugoslav SFR': '248',
#  'Zambia': '251',
#  'Zimbabwe': '181',
#  'World + (Total)': '5000',
#  'World > (List)': '5000>',
#  'Africa + (Total)': '5100',
#  'Africa > (List)': '5100>',
#  '-- Eastern Africa + (Total)': '5101',
#  '-- Eastern Africa > (List)': '5101>',
#  '-- Middle Africa + (Total)': '5102',
#  '-- Middle Africa > (List)': '5102>',
#  '-- Northern Africa + (Total)': '5103',
#  '-- Northern Africa > (List)': '5103>',
#  '-- Southern Africa + (Total)': '5104',
#  '-- Southern Africa > (List)': '5104>',
#  '-- Western Africa + (Total)': '5105',
#  '-- Western Africa > (List)': '5105>',
#  'Americas + (Total)': '5200',
#  'Americas > (List)': '5200>',
#  '-- Northern America + (Total)': '5203',
#  '-- Northern America > (List)': '5203>',
#  '-- Central America + (Total)': '5204',
#  '-- Central America > (List)': '5204>',
#  '-- Caribbean + (Total)': '5206',
#  '-- Caribbean > (List)': '5206>',
#  '-- South America + (Total)': '5207',
#  '-- South America > (List)': '5207>',
#  'Asia + (Total)': '5300',
#  'Asia > (List)': '5300>',
#  '-- Central Asia + (Total)': '5301',
#  '-- Central Asia > (List)': '5301>',
#  '-- Eastern Asia + (Total)': '5302',
#  '-- Eastern Asia > (List)': '5302>',
#  '-- Southern Asia + (Total)': '5303',
#  '-- Southern Asia > (List)': '5303>',
#  '-- South-eastern Asia + (Total)': '5304',
#  '-- South-eastern Asia > (List)': '5304>',
#  '-- Western Asia + (Total)': '5305',
#  '-- Western Asia > (List)': '5305>',
#  'Europe + (Total)': '5400',
#  'Europe > (List)': '5400>',
#  '-- Eastern Europe + (Total)': '5401',
#  '-- Eastern Europe > (List)': '5401>',
#  '-- Northern Europe + (Total)': '5402',
#  '-- Northern Europe > (List)': '5402>',
#  '-- Southern Europe + (Total)': '5403',
#  '-- Southern Europe > (List)': '5403>',
#  '-- Western Europe + (Total)': '5404',
#  '-- Western Europe > (List)': '5404>',
#  'Oceania + (Total)': '5500',
#  'Oceania > (List)': '5500>',
#  '-- Australia and New Zealand + (Total)': '5501',
#  '-- Australia and New Zealand > (List)': '5501>',
#  '-- Melanesia + (Total)': '5502',
#  '-- Melanesia > (List)': '5502>',
#  '-- Micronesia + (Total)': '5503',
#  '-- Micronesia > (List)': '5503>',
#  '-- Polynesia + (Total)': '5504',
#  '-- Polynesia > (List)': '5504>',
#  'European Union (27) + (Total)': '5707',
#  'European Union (27) > (List)': '5707>',
#  'Least Developed Countries + (Total)': '5801',
#  'Least Developed Countries > (List)': '5801>',
#  'Land Locked Developing Countries + (Total)': '5802',
#  'Land Locked Developing Countries > (List)': '5802>',
#  'Small Island Developing States + (Total)': '5803',
#  'Small Island Developing States > (List)': '5803>',
#  'Low Income Food Deficit Countries + (Total)': '5815',
#  'Low Income Food Deficit Countries > (List)': '5815>',
#  'Net Food Importing Developing Countries + (Total)': '5817',
#  'Net Food Importing Developing Countries > (List)': '5817>'}

# %% [markdown]
# ## Load QCL Data
# ---

# %% [markdown]
# List relevant item codes and relevant elements from FAOSTAT

# %%
# List relevant item codes
QCL_item = {
    'Soya beans': '236',
    'Oil palm fruit': '254',
    'Cocoa beans': '661',
    'Coffee, green': '656',
    'Maize (corn)': '56',
    'Green corn (maize)': '446',
    'Rice': '27',
    'Cattle and Buffaloes': '1746'
}
# List relevant element codes (Harvested Area for crops, and Stocks for livestock)
QCL_element = {
    'harvested_area': 2312,
    'stocks': 2111
}

# %% [markdown]
# Setup parameters

# %%
QCL_pars={'area': [y for y in [x for x in faostat.get_par('QCL', 'area').values() if x.isdigit()] if int(y) < 1000],
        'element': [*QCL_element.values()],
        'item': [*QCL_item.values()]}

# %% [markdown]
# Load data to datafame

# %%
QCL_df = faostat.get_data_df('QCL', pars=QCL_pars)
QCL_df
# Out:
#       Domain Code                        Domain Area Code         Area  \
# 0             QCL  Crops and livestock products         2  Afghanistan
# 1             QCL  Crops and livestock products         2  Afghanistan
# 2             QCL  Crops and livestock products         2  Afghanistan
# 3             QCL  Crops and livestock products         2  Afghanistan
# 4             QCL  Crops and livestock products         2  Afghanistan
# ...           ...                           ...       ...          ...
# 48998         QCL  Crops and livestock products       181     Zimbabwe
# 48999         QCL  Crops and livestock products       181     Zimbabwe
# 49000         QCL  Crops and livestock products       181     Zimbabwe
# 49001         QCL  Crops and livestock products       181     Zimbabwe
# 49002         QCL  Crops and livestock products       181     Zimbabwe
#
#       Element Code         Element Item Code                  Item Year Code  \
# 0             5312  Area harvested        56          Maize (corn)      1961
# 1             5312  Area harvested        56          Maize (corn)      1962
# 2             5312  Area harvested        56          Maize (corn)      1963
# 3             5312  Area harvested        56          Maize (corn)      1964
# 4             5312  Area harvested        56          Maize (corn)      1965
# ...            ...             ...       ...                   ...       ...
# 48998         5111          Stocks      1746  Cattle and Buffaloes      2018
# 48999         5111          Stocks      1746  Cattle and Buffaloes      2019
# 49000         5111          Stocks      1746  Cattle and Buffaloes      2020
# 49001         5111          Stocks      1746  Cattle and Buffaloes      2021
# 49002         5111          Stocks      1746  Cattle and Buffaloes      2022
#
#        Year Unit    Value
# 0      1961   ha   500000
# 1      1962   ha   500000
# 2      1963   ha   500000
# 3      1964   ha   505000
# 4      1965   ha   500000
# ...     ...  ...      ...
# 48998  2018   An  5320047
# 48999  2019   An  5057563
# 49000  2020   An  5195154
# 49001  2021   An  5354738
# 49002  2022   An  5438771
#
# [49003 rows x 12 columns]

# %% [markdown]
# ## Export QCL Data
# ---

# %%
QCL_df.to_csv('data/faostat/QCL_raw.csv',index=False)

# %%
QCL_df[['Area','Item','Year','Unit','Value']].to_csv('data/faostat/QCL_init.csv',index=False)

# %% [markdown]
# ## Inspect RL Data
# ---

# %%
faostat.list_pars('RL')
# Out:
# [('parameter code', 'coding_systems', 'subdimensions {code: meaning}'),
#  ('area',
#   ['M49', 'FAO', 'ISO2', 'ISO3'],
#   {'countries': 'Countries',
#    'regions': 'Regions',
#    'specialgroups': 'Special Groups'}),
#  ('element', [], {'elements': 'Elements'}),
#  ('item', [], {'items': 'Items', 'itemsagg': 'Items Aggregated'}),
#  ('year', [], {'years': 'Years'})]

# %%
faostat.get_par('RL','element')
# Out:
# {'Area': '5110',
#  'Carbon stock in living biomass': '7215',
#  'Indicators > (List)': '72000>',
#  '-- Share in Agricultural land': '7208',
#  '-- Share in Land area': '7209',
#  '-- Share in Forest land': '7210',
#  '-- Share in Cropland': '7252',
#  '-- Area per capita': '7277',
#  '-- Value of agricultural production (Int. $) per Area': '7278'}

# %%
faostat.get_par('RL','item')
# Out:
# {'Country area': '6600',
#  'Land area': '6601',
#  'Agriculture > (List)': '66020>',
#  'Agriculture': '6602',
#  '- Agricultural land': '6610',
#  '-- Cropland': '6620',
#  '--- Arable land': '6621',
#  '--- Temporary crops': '6630',
#  '--- Temporary meadows and pastures': '6633',
#  '--- Temporary fallow': '6640',
#  '--- Permanent crops': '6650',
#  '-- Permanent meadows and pastures': '6655',
#  '--- Perm. meadows & pastures - Cultivated': '6656',
#  '--- Perm. meadows & pastures - Nat. growing': '6659',
#  '- Farm buildings and Farmyards': '6649',
#  'Forestland > (List)': '66630>',
#  'Forest land': '6646',
#  '- Naturally regenerating forest': '6717',
#  '- Planted Forest': '6716',
#  'Other land': '6670',
#  'Water > (List)': '66800>',
#  'Inland waters': '6680',
#  'Coastal waters': '6773',
#  'Exclusive Economic Zone (EEZ)': '6643',
#  'Irrigation > (List)': '66900>',
#  'Land area equipped for irrigation': '6690',
#  'Land area actually irrigated': '6616',
#  'Agriculture area actually irrigated': '6611',
#  'Cropland area actually irrigated': '6694',
#  'Perm. meadows & pastures area actually irrig.': '6657',
#  'Forestry area actually irrigated': '6695',
#  'Agricultural practices > (List)': '66710>',
#  'Agriculture area under organic agric.': '6671',
#  'Agriculture area certified organic': '6672',
#  'Cropland area under organic agric.': '6668',
#  'Cropland area certified organic': '6669',
#  'Perm. meadows & pastures area under organic agric.': '6681',
#  'Perm. meadows & pastures area certified organic': '6682',
#  'Cropland area under conventional tillage': '6664',
#  'Cropland area under conservation tillage': '6665',
#  'Cropland area under zero or no tillage': '6666',
#  'Cropland area under protective cover': '6774',
#  'Aquaculture and Fisheries > (List)': '67620>',
#  'Land used for aquaculture': '6762',
#  'Inland waters used for aquac. or holding facilities': '6767',
#  'Inland waters used for capture fisheries': '6771',
#  'Coastal waters used for aquac. or holding facilities': '6641',
#  'Coastal waters used for capture fisheries': '6642',
#  'EEZ used for aquac. or holding facilities': '6644',
#  'EEZ used for capture fisheries': '6645',
#  'Archive data > (List)': '68000>',
#  'Primary Forest': '6714'}

# %%
faostat.get_par('RL', 'area')
# Out:
# {'Afghanistan': '2',
#  'Albania': '3',
#  'Algeria': '4',
#  'American Samoa': '5',
#  'Andorra': '6',
#  'Angola': '7',
#  'Anguilla': '258',
#  'Antigua and Barbuda': '8',
#  'Argentina': '9',
#  'Armenia': '1',
#  'Aruba': '22',
#  'Australia': '10',
#  'Austria': '11',
#  'Azerbaijan': '52',
#  'Bahamas': '12',
#  'Bahrain': '13',
#  'Bangladesh': '16',
#  'Barbados': '14',
#  'Belarus': '57',
#  'Belgium': '255',
#  'Belgium-Luxembourg': '15',
#  'Belize': '23',
#  'Benin': '53',
#  'Bermuda': '17',
#  'Bhutan': '18',
#  'Bolivia (Plurinational State of)': '19',
#  'Bonaire, Sint Eustatius and Saba': '278',
#  'Bosnia and Herzegovina': '80',
#  'Botswana': '20',
#  'Brazil': '21',
#  'British Virgin Islands': '239',
#  'Brunei Darussalam': '26',
#  'Bulgaria': '27',
#  'Burkina Faso': '233',
#  'Burundi': '29',
#  'Cabo Verde': '35',
#  'Cambodia': '115',
#  'Cameroon': '32',
#  'Canada': '33',
#  'Cayman Islands': '36',
#  'Central African Republic': '37',
#  'Chad': '39',
#  'Channel Islands': '259',
#  'Chile': '40',
#  'China': '351',
#  'China, Hong Kong SAR': '96',
#  'China, Macao SAR': '128',
#  'China, mainland': '41',
#  'China, Taiwan Province of': '214',
#  'Colombia': '44',
#  'Comoros': '45',
#  'Congo': '46',
#  'Cook Islands': '47',
#  'Costa Rica': '48',
#  "Côte d'Ivoire": '107',
#  'Croatia': '98',
#  'Cuba': '49',
#  'Curaçao': '279',
#  'Cyprus': '50',
#  'Czechia': '167',
#  'Czechoslovakia': '51',
#  "Democratic People's Republic of Korea": '116',
#  'Democratic Republic of the Congo': '250',
#  'Denmark': '54',
#  'Djibouti': '72',
#  'Dominica': '55',
#  'Dominican Republic': '56',
#  'Ecuador': '58',
#  'Egypt': '59',
#  'El Salvador': '60',
#  'Equatorial Guinea': '61',
#  'Eritrea': '178',
#  'Estonia': '63',
#  'Eswatini': '209',
#  'Ethiopia': '238',
#  'Ethiopia PDR': '62',
#  'Falkland Islands (Malvinas)': '65',
#  'Faroe Islands': '64',
#  'Fiji': '66',
#  'Finland': '67',
#  'France': '68',
#  'French Guiana': '69',
#  'French Polynesia': '70',
#  'Gabon': '74',
#  'Gambia': '75',
#  'Georgia': '73',
#  'Germany': '79',
#  'Ghana': '81',
#  'Gibraltar': '82',
#  'Greece': '84',
#  'Greenland': '85',
#  'Grenada': '86',
#  'Guadeloupe': '87',
#  'Guam': '88',
#  'Guatemala': '89',
#  'Guinea': '90',
#  'Guinea-Bissau': '175',
#  'Guyana': '91',
#  'Haiti': '93',
#  'Holy See': '94',
#  'Honduras': '95',
#  'Hungary': '97',
#  'Iceland': '99',
#  'India': '100',
#  'Indonesia': '101',
#  'Iran (Islamic Republic of)': '102',
#  'Iraq': '103',
#  'Ireland': '104',
#  'Isle of Man': '264',
#  'Israel': '105',
#  'Italy': '106',
#  'Jamaica': '109',
#  'Japan': '110',
#  'Jordan': '112',
#  'Kazakhstan': '108',
#  'Kenya': '114',
#  'Kiribati': '83',
#  'Kuwait': '118',
#  'Kyrgyzstan': '113',
#  "Lao People's Democratic Republic": '120',
#  'Latvia': '119',
#  'Lebanon': '121',
#  'Lesotho': '122',
#  'Liberia': '123',
#  'Libya': '124',
#  'Liechtenstein': '125',
#  'Lithuania': '126',
#  'Luxembourg': '256',
#  'Madagascar': '129',
#  'Malawi': '130',
#  'Malaysia': '131',
#  'Maldives': '132',
#  'Mali': '133',
#  'Malta': '134',
#  'Marshall Islands': '127',
#  'Martinique': '135',
#  'Mauritania': '136',
#  'Mauritius': '137',
#  'Mayotte': '270',
#  'Mexico': '138',
#  'Micronesia (Federated States of)': '145',
#  'Monaco': '140',
#  'Mongolia': '141',
#  'Montenegro': '273',
#  'Montserrat': '142',
#  'Morocco': '143',
#  'Mozambique': '144',
#  'Myanmar': '28',
#  'Namibia': '147',
#  'Nauru': '148',
#  'Nepal': '149',
#  'Netherlands (Kingdom of the)': '150',
#  'Netherlands Antilles (former)': '151',
#  'New Caledonia': '153',
#  'New Zealand': '156',
#  'Nicaragua': '157',
#  'Niger': '158',
#  'Nigeria': '159',
#  'Niue': '160',
#  'Norfolk Island': '161',
#  'North Macedonia': '154',
#  'Northern Mariana Islands': '163',
#  'Norway': '162',
#  'Oman': '221',
#  'Pacific Islands Trust Territory': '164',
#  'Pakistan': '165',
#  'Palau': '180',
#  'Palestine': '299',
#  'Panama': '166',
#  'Papua New Guinea': '168',
#  'Paraguay': '169',
#  'Peru': '170',
#  'Philippines': '171',
#  'Pitcairn': '172',
#  'Poland': '173',
#  'Portugal': '174',
#  'Puerto Rico': '177',
#  'Qatar': '179',
#  'Republic of Korea': '117',
#  'Republic of Moldova': '146',
#  'Réunion': '182',
#  'Romania': '183',
#  'Russian Federation': '185',
#  'Rwanda': '184',
#  'Saint Barthélemy': '282',
#  'Saint Helena, Ascension and Tristan da Cunha': '187',
#  'Saint Kitts and Nevis': '188',
#  'Saint Lucia': '189',
#  'Saint Martin (French part)': '281',
#  'Saint Pierre and Miquelon': '190',
#  'Saint Vincent and the Grenadines': '191',
#  'Samoa': '244',
#  'San Marino': '192',
#  'Sao Tome and Principe': '193',
#  'Saudi Arabia': '194',
#  'Senegal': '195',
#  'Serbia': '272',
#  'Serbia and Montenegro': '186',
#  'Seychelles': '196',
#  'Sierra Leone': '197',
#  'Singapore': '200',
#  'Sint Maarten (Dutch part)': '280',
#  'Slovakia': '199',
#  'Slovenia': '198',
#  'Solomon Islands': '25',
#  'Somalia': '201',
#  'South Africa': '202',
#  'South Sudan': '277',
#  'Spain': '203',
#  'Sri Lanka': '38',
#  'Sudan': '276',
#  'Sudan (former)': '206',
#  'Suriname': '207',
#  'Sweden': '210',
#  'Switzerland': '211',
#  'Syrian Arab Republic': '212',
#  'Tajikistan': '208',
#  'Thailand': '216',
#  'Timor-Leste': '176',
#  'Togo': '217',
#  'Tokelau': '218',
#  'Tonga': '219',
#  'Trinidad and Tobago': '220',
#  'Tunisia': '222',
#  'Türkiye': '223',
#  'Turkmenistan': '213',
#  'Turks and Caicos Islands': '224',
#  'Tuvalu': '227',
#  'Uganda': '226',
#  'Ukraine': '230',
#  'United Arab Emirates': '225',
#  'United Kingdom of Great Britain and Northern Ireland': '229',
#  'United Republic of Tanzania': '215',
#  'United States of America': '231',
#  'United States Virgin Islands': '240',
#  'Uruguay': '234',
#  'USSR': '228',
#  'Uzbekistan': '235',
#  'Vanuatu': '155',
#  'Venezuela (Bolivarian Republic of)': '236',
#  'Viet Nam': '237',
#  'Wallis and Futuna Islands': '243',
#  'Western Sahara': '205',
#  'Yemen': '249',
#  'Yugoslav SFR': '248',
#  'Zambia': '251',
#  'Zimbabwe': '181',
#  'World + (Total)': '5000',
#  'World > (List)': '5000>',
#  'Africa + (Total)': '5100',
#  'Africa > (List)': '5100>',
#  '-- Eastern Africa + (Total)': '5101',
#  '-- Eastern Africa > (List)': '5101>',
#  '-- Middle Africa + (Total)': '5102',
#  '-- Middle Africa > (List)': '5102>',
#  '-- Northern Africa + (Total)': '5103',
#  '-- Northern Africa > (List)': '5103>',
#  '-- Southern Africa + (Total)': '5104',
#  '-- Southern Africa > (List)': '5104>',
#  '-- Western Africa + (Total)': '5105',
#  '-- Western Africa > (List)': '5105>',
#  'Americas + (Total)': '5200',
#  'Americas > (List)': '5200>',
#  '-- Northern America + (Total)': '5203',
#  '-- Northern America > (List)': '5203>',
#  '-- Central America + (Total)': '5204',
#  '-- Central America > (List)': '5204>',
#  '-- Caribbean + (Total)': '5206',
#  '-- Caribbean > (List)': '5206>',
#  '-- South America + (Total)': '5207',
#  '-- South America > (List)': '5207>',
#  'Asia + (Total)': '5300',
#  'Asia > (List)': '5300>',
#  '-- Central Asia + (Total)': '5301',
#  '-- Central Asia > (List)': '5301>',
#  '-- Eastern Asia + (Total)': '5302',
#  '-- Eastern Asia > (List)': '5302>',
#  '-- Southern Asia + (Total)': '5303',
#  '-- Southern Asia > (List)': '5303>',
#  '-- South-eastern Asia + (Total)': '5304',
#  '-- South-eastern Asia > (List)': '5304>',
#  '-- Western Asia + (Total)': '5305',
#  '-- Western Asia > (List)': '5305>',
#  'Europe + (Total)': '5400',
#  'Europe > (List)': '5400>',
#  '-- Eastern Europe + (Total)': '5401',
#  '-- Eastern Europe > (List)': '5401>',
#  '-- Northern Europe + (Total)': '5402',
#  '-- Northern Europe > (List)': '5402>',
#  '-- Southern Europe + (Total)': '5403',
#  '-- Southern Europe > (List)': '5403>',
#  '-- Western Europe + (Total)': '5404',
#  '-- Western Europe > (List)': '5404>',
#  'Oceania + (Total)': '5500',
#  'Oceania > (List)': '5500>',
#  '-- Australia and New Zealand + (Total)': '5501',
#  '-- Australia and New Zealand > (List)': '5501>',
#  '-- Melanesia + (Total)': '5502',
#  '-- Melanesia > (List)': '5502>',
#  '-- Micronesia + (Total)': '5503',
#  '-- Micronesia > (List)': '5503>',
#  '-- Polynesia + (Total)': '5504',
#  '-- Polynesia > (List)': '5504>',
#  'European Union (27) + (Total)': '5707',
#  'European Union (27) > (List)': '5707>',
#  'Least Developed Countries + (Total)': '5801',
#  'Least Developed Countries > (List)': '5801>',
#  'Land Locked Developing Countries + (Total)': '5802',
#  'Land Locked Developing Countries > (List)': '5802>',
#  'Small Island Developing States + (Total)': '5803',
#  'Small Island Developing States > (List)': '5803>',
#  'Low Income Food Deficit Countries + (Total)': '5815',
#  'Low Income Food Deficit Countries > (List)': '5815>',
#  'Net Food Importing Developing Countries + (Total)': '5817',
#  'Net Food Importing Developing Countries > (List)': '5817>'}

# %% [markdown]
# ## Load RL Data
# ---

# %%
# List relevant item codes and relevant elements from FAOSTAT
RL_item = {
    'Land area': '6601',
    # 'Agriculture': '6602',
    'Cropland': '6620',
    'Permanent meadows and pastures': '6655',
    'Farm buildings and Farmyards': '6649',
    'Forest land': '6646',
    'Other land': '6670',
    'Primary Forest': '6714',
    'Naturally regenerating forest': '6717',
     'Planted Forest': '6716',
    'Land used for aquaculture': '6762',
}
# Define elements for Harvested Area for crops, and Stocks for livestock
RL_element = {
    'Area': '5110'
}

# %%
RL_pars={'area': [y for y in [x for x in faostat.get_par('RL', 'area').values() if x.isdigit()] if int(y) < 1000],
         'element': [*RL_element.values()],
         'item': [*RL_item.values()]}

# %%
RL_df = faostat.get_data_df('RL', pars=RL_pars)
RL_df
# Out:
#       Domain Code    Domain Area Code         Area Element Code Element  \
# 0              RL  Land Use         2  Afghanistan         5110    Area
# 1              RL  Land Use         2  Afghanistan         5110    Area
# 2              RL  Land Use         2  Afghanistan         5110    Area
# 3              RL  Land Use         2  Afghanistan         5110    Area
# 4              RL  Land Use         2  Afghanistan         5110    Area
# ...           ...       ...       ...          ...          ...     ...
# 75127          RL  Land Use       181     Zimbabwe         5110    Area
# 75128          RL  Land Use       181     Zimbabwe         5110    Area
# 75129          RL  Land Use       181     Zimbabwe         5110    Area
# 75130          RL  Land Use       181     Zimbabwe         5110    Area
# 75131          RL  Land Use       181     Zimbabwe         5110    Area
#
#       Item Code            Item Year Code  Year     Unit  Value
# 0          6601       Land area      1961  1961  1000 ha  65223
# 1          6601       Land area      1962  1962  1000 ha  65223
# 2          6601       Land area      1963  1963  1000 ha  65223
# 3          6601       Land area      1964  1964  1000 ha  65223
# 4          6601       Land area      1965  1965  1000 ha  65223
# ...         ...             ...       ...   ...      ...    ...
# 75127      6714  Primary Forest      2013  2013  1000 ha    801
# 75128      6714  Primary Forest      2014  2014  1000 ha    801
# 75129      6714  Primary Forest      2015  2015  1000 ha    801
# 75130      6714  Primary Forest      2016  2016  1000 ha    801
# 75131      6714  Primary Forest      2017  2017  1000 ha    801
#
# [75132 rows x 12 columns]

# %%
RL_df.loc[(RL_df.Area=='Zimbabwe') & (RL_df.Year=='2017')]
# Out:
#       Domain Code    Domain Area Code      Area Element Code Element  \
# 74835          RL  Land Use       181  Zimbabwe         5110    Area
# 74897          RL  Land Use       181  Zimbabwe         5110    Area
# 74959          RL  Land Use       181  Zimbabwe         5110    Area
# 74992          RL  Land Use       181  Zimbabwe         5110    Area
# 75025          RL  Land Use       181  Zimbabwe         5110    Area
# 75058          RL  Land Use       181  Zimbabwe         5110    Area
# 75091          RL  Land Use       181  Zimbabwe         5110    Area
# 75098          RL  Land Use       181  Zimbabwe         5110    Area
# 75131          RL  Land Use       181  Zimbabwe         5110    Area
#
#       Item Code                            Item Year Code  Year     Unit  \
# 74835      6601                       Land area      2017  2017  1000 ha
# 74897      6620                        Cropland      2017  2017  1000 ha
# 74959      6655  Permanent meadows and pastures      2017  2017  1000 ha
# 74992      6646                     Forest land      2017  2017  1000 ha
# 75025      6717   Naturally regenerating forest      2017  2017  1000 ha
# 75058      6716                  Planted Forest      2017  2017  1000 ha
# 75091      6670                      Other land      2017  2017  1000 ha
# 75098      6762       Land used for aquaculture      2017  2017  1000 ha
# 75131      6714                  Primary Forest      2017  2017  1000 ha
#
#            Value
# 74835      38685
# 74897  3300.0759
# 74959      12100
# 74992   17582.79
# 75025   17474.79
# 75058        108
# 75091  5702.1341
# 75098     0.0641
# 75131        801

# %%
RL_df['Item'].unique()
# Out:
# array(['Land area', 'Cropland', 'Permanent meadows and pastures',
#        'Forest land', 'Naturally regenerating forest', 'Planted Forest',
#        'Other land', 'Primary Forest', 'Farm buildings and Farmyards',
#        'Land used for aquaculture'], dtype=object)

# %%
RL_df.loc[RL_df.Item=='Primary Forest']
# Out:
#       Domain Code    Domain Area Code         Area Element Code Element  \
# 318            RL  Land Use         2  Afghanistan         5110    Area
# 319            RL  Land Use         2  Afghanistan         5110    Area
# 320            RL  Land Use         2  Afghanistan         5110    Area
# 321            RL  Land Use         2  Afghanistan         5110    Area
# 322            RL  Land Use         2  Afghanistan         5110    Area
# ...           ...       ...       ...          ...          ...     ...
# 75127          RL  Land Use       181     Zimbabwe         5110    Area
# 75128          RL  Land Use       181     Zimbabwe         5110    Area
# 75129          RL  Land Use       181     Zimbabwe         5110    Area
# 75130          RL  Land Use       181     Zimbabwe         5110    Area
# 75131          RL  Land Use       181     Zimbabwe         5110    Area
#
#       Item Code            Item Year Code  Year     Unit Value
# 318        6714  Primary Forest      1990  1990  1000 ha     0
# 319        6714  Primary Forest      1991  1991  1000 ha     0
# 320        6714  Primary Forest      1992  1992  1000 ha     0
# 321        6714  Primary Forest      1993  1993  1000 ha     0
# 322        6714  Primary Forest      1994  1994  1000 ha     0
# ...         ...             ...       ...   ...      ...   ...
# 75127      6714  Primary Forest      2013  2013  1000 ha   801
# 75128      6714  Primary Forest      2014  2014  1000 ha   801
# 75129      6714  Primary Forest      2015  2015  1000 ha   801
# 75130      6714  Primary Forest      2016  2016  1000 ha   801
# 75131      6714  Primary Forest      2017  2017  1000 ha   801
#
# [6284 rows x 12 columns]

# %% [markdown]
# ## Export RL Data
# ---

# %%
RL_df.to_csv('data/faostat/RL_raw.csv',index=False)

# %%
RL_df[['Area','Item','Year','Unit','Value']].to_csv('data/faostat/RL_init.csv',index=False)
